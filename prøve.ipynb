# %% [markdown]
# # 2023 eksamen
#
# ## Opgave 1

# %%
import numpy as np
import pandas as pd

# Load the dataset
df = pd.read_stata('HomeVisit.dta', convert_dates=True)

# If you suspect that there are encoding issues, you can convert object columns
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].str.encode('latin-1').str.decode('utf-8', errors='ignore')

df.describe().T.round(3)
# Out:
# /var/folders/nk/d0gbqgzj30d21jjn_bxj9dmc0000gn/T/ipykernel_5477/2581101886.py:5: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df = pd.read_stata('HomeVisit.dta', convert_dates=True)
#                    count      mean     std       min       25%       50%  \
# Year              1479.0  1941.000   4.901  1933.000  1937.000  1941.000
# StartYear         1479.0  1949.839  13.222  1937.000  1940.000  1945.000
# HomeVisit         1479.0     0.318   0.466     0.000     0.000     0.000
# LogSurvrate       1305.0     6.842   0.034     6.493     6.827     6.847
# LogPopulation     1479.0     8.828   1.194     6.551     7.972     8.825
# OverallDeathRate  1479.0    11.744   2.637     2.222    10.000    11.304
# ...

# %%
df = pd.read_stata('HomeVisit.dta')

print(df.columns)
# Out:
# Index(['Kom', 'Year', 'StartYear', 'HomeVisit', 'LogSurvrate', 'LogPopulation',
#        'OverallDeathRate', 'ShareSocdem', 'ShareFarming', 'ShareIndustry',
#        'ShareIncometax', 'ShareProperty', 'Rural'],
#       dtype='object')
# /var/folders/nk/d0gbqgzj30d21jjn_bxj9dmc0000gn/T/ipykernel_5477/4062697011.py:1: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df = pd.read_stata('HomeVisit.dta')
